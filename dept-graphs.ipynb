# %%
import numpy as np
import networkx as nx
from networkx.algorithms import community #use community algorithm to detect communities within a graph
import itertools
import matplotlib.pyplot as plt

FileName="email-Eu-core-temporal-Dept1.txt"
Graphtype=nx.DiGraph()   # use net.Graph() for undirected graph

# How to read from a file. Note: if your egde weights are int, change float to int.
G1 = nx.read_edgelist(FileName, create_using=Graphtype, nodetype=int, data=(('weight',int),))

#for k in range(2,20):
    #c = list(community.k_clique_communities(G1, k))
    #print(c)

print(nx.number_strongly_connected_components(G1))
print(nx.number_weakly_connected_components(G1))
print(nx.number_attracting_components(G1))
# Out:
# 81
# 9
# 56

# %%
FileName="email-Eu-core-temporal-Dept2.txt"
Graphtype=nx.DiGraph()   # use net.DiGraph() for directed graph

# How to read from a file. Note: if your egde weights are int, change float to int.
G2 = nx.read_edgelist(FileName, create_using=Graphtype, nodetype=int, data=(('weight',int),))

#for k in range(2,20):
    #c = list(community.k_clique_communities(G2, k))
    #print(c)

print(nx.number_strongly_connected_components(G2))
print(nx.number_weakly_connected_components(G2))
print(nx.number_attracting_components(G2))
# Out:
# 45
# 6
# 30

# %%
FileName="email-Eu-core-temporal-Dept3.txt"
Graphtype=nx.DiGraph()   # use net.DiGraph() for directed graph

# How to read from a file. Note: if your egde weights are int, change float to int.
G3 = nx.read_edgelist(FileName, create_using=Graphtype, nodetype=int, data=(('weight',int),))

#for k in range(2,20):
    #c = list(community.k_clique_communities(G3, k))
    #print(c)

print(nx.number_strongly_connected_components(G3))
print(nx.number_weakly_connected_components(G3))
print(nx.number_attracting_components(G3))
# Out:
# 11
# 1
# 10

# %%
FileName="email-Eu-core-temporal-Dept4.txt"
Graphtype=nx.DiGraph()   # use net.DiGraph() for directed graph

# How to read from a file. Note: if your egde weights are int, change float to int.
G4 = nx.read_edgelist(FileName, create_using=Graphtype, nodetype=int, data=(('weight',int),))

#for k in range(2,20):
    #c = list(community.k_clique_communities(G4, k))
    #print(c)

print(nx.number_strongly_connected_components(G4))
print(nx.number_weakly_connected_components(G4))
print(nx.number_attracting_components(G4))
# Out:
# 24
# 6
# 17

# %%
nx.draw_kamada_kawai(G1, node_size = 4, arrowsize = 4, width = 0.2)
plt.draw()
#plt.show()
plt.savefig('G1.png', dpi=800)

# %%
nx.draw_kamada_kawai(G2, node_size = 4, arrowsize = 4, width = 0.2)
plt.draw()
#plt.show()
plt.savefig('G2.png', dpi=800)

# %%
nx.draw_kamada_kawai(G3, node_size = 4, arrowsize = 4, width = 0.2)
plt.draw()
#plt.show()
plt.savefig('G3.png', dpi=800)

# %%
nx.draw_kamada_kawai(G4, node_size = 4, arrowsize = 4, width = 0.2)
plt.draw()
#plt.show()
plt.savefig('G4.png', dpi=800)

# %%
nx.graph_edit_distance(G1,G2)

# %%
nx.graph_edit_distance(G1,G3)

# %%
nx.graph_edit_distance(G1,G4)

# %%
nx.graph_edit_distance(G2,G3)

# %%
nx.graph_edit_distance(G2,G4)

# %%
nx.graph_edit_distance(G3,G4)
